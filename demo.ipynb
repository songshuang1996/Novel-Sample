# %% [markdown]
# # demo.ipynb — Core Pipeline Functions
#
# This notebook contains every function used by the pipeline. It is **imported** by
# `main_program.ipynb` via `import_ipynb` — you do not need to run it manually.
#
# ## Function index
#
# | Function | Purpose |
# |---|---|
# | `check_before_task` | Validate user inputs before any heavy computation |
# | `download_gbk` | Download reference genomes (GenBank format) from NCBI |
# | `all` | Parse a GenBank file → protein FASTA + promoter FASTA |
# | `extract_protein` | Run `all()` in parallel over every genome in a taxon |
# | `get_selected_protein` | Fetch user-supplied protein sequences from NCBI Entrez |
# | `diamond_task` | Build a DIAMOND protein database for the taxon |
# | `find_promoter` | Look up a promoter or protein sequence by genome + protein ID |
# | `get_selected_protein_diamond` | DIAMOND search → promoter extraction → CD-HIT clustering |
# | `meme_work` | Run MEME on one gene combination |
# | `combine_meme_work` | Orchestrate all combinations (or comparative-only) in parallel |
# | `motif_for_R` | Call `motif.R` to filter, merge, and plot motifs |
# | `summary_R_result` | Aggregate per-motif frequency tables into `summary.txt` |

# %% [markdown]
# ## Configuration
#
# All paths are loaded from `config.py` (git-ignored, created by the user).
# See `config.example.py` for the template.

# %%
import os

# ---------------------------------------------------------------------------
# Load user configuration from config.py
# ---------------------------------------------------------------------------
try:
    import config
    BASE_DIR = config.BASE_DIR    # root directory for all pipeline data
    MEME_BIN = config.MEME_BIN   # full path to the meme executable
    RSCRIPT  = config.RSCRIPT    # full path to Rscript
    MOTIF_R  = config.MOTIF_R    # full path to motif.R
    EMAIL    = config.EMAIL      # email for NCBI Entrez API
    THREADS  = config.THREADS    # CPU thread count
except ImportError:
    raise RuntimeError(
        "config.py not found. "
        "Please copy config.example.py to config.py and fill in your paths."
    )

# %% [markdown]
# ## 1 — Input Validation

# %%
def check_before_task(taxonomy: str, protein_list: list, set_length: int) -> str:
    """
    Validate all user inputs before any expensive computation begins.

    Checks performed
    ----------------
    1. Protein list length  : must not exceed 80 entries.
    2. Taxon genome count   : NCBI must have between 5 and 100 reference
                              genomes for the requested taxon.  Fewer than 5
                              gives insufficient comparative power; more than
                              100 would make the job too slow for a web service.
    3. Combination size     : set_length must be <= 3 to keep the number of
                              MEME jobs manageable (C(n, k) grows quickly).
    4. NCBI connectivity    : a test Entrez fetch verifies the server can reach
                              NCBI before the job is accepted.

    Parameters
    ----------
    taxonomy    : NCBI taxon name (e.g. "Acinetobacter")
    protein_list: list of RefSeq protein accessions
    set_length  : number of genes per combination (0, 1, 2, or 3)

    Returns
    -------
    'True' if all checks pass, otherwise a human-readable error string.
    """
    os.chdir(BASE_DIR)

    # --- Check 1: protein list size ---
    if len(protein_list) > 80:
        return 'Too many proteins (limit: 80). Please reduce the list and resubmit.'

    # --- Check 2: taxon genome count ---
    # Use the NCBI Datasets CLI in preview mode (no download) to count
    # how many reference genomes exist for this taxon in RefSeq.
    os.system(
        'datasets download genome taxon %s '
        '--assembly-source refseq --include gbff --reference --preview > preview'
        % taxonomy
    )
    data = open('preview').read()
    try:
        tax_count = int(data.split(',')[1].split(':')[1])
    except (IndexError, ValueError):
        os.system('rm -f preview')
        return 'Could not parse NCBI preview response. Check the taxonomy name.'
    os.system('rm -f preview')

    if tax_count < 5:
        return ('Only %d reference genome(s) found for "%s". '
                'Need at least 5 for meaningful comparative analysis.' % (tax_count, taxonomy))
    if tax_count > 100:
        return ('Found %d genomes for "%s" — too many for this web service (limit: 100). '
                'Please use a more specific taxon name.' % (tax_count, taxonomy))

    # --- Check 3: combination size ---
    if set_length > 3:
        return 'Genes per combination must be 0, 1, 2, or 3. Please adjust and resubmit.'

    # --- Check 4: NCBI connectivity ---
    # Fetch a known protein accession as a connectivity test.
    try:
        get_selected_protein('NP_217717.1')
    except Exception:
        return 'Cannot connect to NCBI. Please check your internet connection and try again.'

    return 'True'

# %% [markdown]
# ## 2 — Genome Download

# %%
def download_gbk(taxonomy: str) -> None:
    """
    Download all reference GenBank genomes for a given taxon from NCBI.

    The NCBI Datasets CLI is used to fetch RefSeq reference assemblies in
    GenBank flat-file format (*.gbff).  Each assembly is stored as a single
    file named by its numeric assembly accession (e.g. "2697049").

    Directory layout created inside BASE_DIR
    -----------------------------------------
    0_gbk/<taxonomy>/          — raw GenBank files
    0_protein/<taxonomy>/      — protein FASTA files (filled by extract_protein)
    0_promoter/<taxonomy>/     — promoter FASTA files (filled by extract_protein)

    Parameters
    ----------
    taxonomy : NCBI taxon name (e.g. "Acinetobacter")
    """
    os.chdir(BASE_DIR)

    # Create output directories for this taxon
    for subdir in ['0_gbk', '0_protein', '0_promoter']:
        os.makedirs(os.path.join(BASE_DIR, subdir, taxonomy), exist_ok=True)

    gbk_dir = os.path.join(BASE_DIR, '0_gbk', taxonomy)
    os.chdir(gbk_dir)

    # Download: --reference restricts to one representative genome per species,
    # keeping the dataset manageable.
    os.system(
        'datasets download genome taxon %s '
        '--assembly-source refseq --include gbff --reference' % taxonomy
    )

    # Unpack the downloaded zip archive
    os.system('unzip -q ncbi_dataset.zip')

    # Remove zip and NCBI metadata files that are not needed downstream
    os.system('rm -rf ncbi_dataset.zip README.md '
              'ncbi_dataset/data/dataset_catalog.json '
              'ncbi_dataset/data/assembly_data_report.jsonl')

    # Flatten the directory tree: move each genomic.gbff to a top-level file
    # named by the numeric part of the assembly accession (e.g. GCF_000001405.40 → 000001405)
    for folder in os.listdir('ncbi_dataset/data'):
        genome_id = folder.split('.')[0].split('_')[1]
        os.system('mv ncbi_dataset/data/%s/genomic.gbff ./%s' % (folder, genome_id))

    # Remove the now-empty NCBI dataset directory
    os.system('rm -rf ncbi_dataset')

# %% [markdown]
# ## 3 — Sequence Extraction from GenBank

# %%
from Bio import Entrez, SeqIO
Entrez.email = EMAIL   # required by NCBI for all Entrez API calls


def all(genome_id: str) -> None:
    """
    Parse one GenBank genome file and write two FASTA files:
      - <genome_id>.faa  : protein sequences for every CDS
      - <genome_id>.fa   : 200 bp upstream promoter sequences for every CDS

    Promoter extraction logic
    --------------------------
    For each CDS feature:
      - Forward strand: take the 200 bp immediately upstream of the start codon.
      - Reverse strand: take the 200 bp immediately downstream of the stop codon
        and reverse-complement it (so it reads 5'→3' relative to the gene).

    Quality filters applied
    -----------------------
    - Protein length  < 30 aa  → skipped (likely annotation artefact)
    - Promoter length < 60 bp  → skipped (not enough sequence for motif finding)
    - CDS features without a 'protein_id' qualifier → skipped

    FASTA header format
    -------------------
    ><genome_id>__<protein_id>
    (double underscore separates genome from protein for easy splitting later)

    Parameters
    ----------
    genome_id : base name of the GenBank file (no extension), e.g. "000001405"
    """
    try:
        protein_data = ''
        promoter_data = ''

        for seq_record in SeqIO.parse(genome_id, 'genbank'):
            for feature in seq_record.features:
                if feature.type != 'CDS':
                    continue
                if 'protein_id' not in feature.qualifiers:
                    continue

                protein_seq = feature.qualifiers['translation'][0]

                # Determine strand and extract the upstream promoter region
                if '-' in str(feature.location):   # reverse (minus) strand
                    promoter_seq = seq_record.seq[
                        feature.location.end : feature.location.end + 200
                    ].reverse_complement()
                else:                               # forward (plus) strand
                    promoter_seq = seq_record.seq[
                        feature.location.start - 200 : feature.location.start
                    ]

                # Apply quality filters
                if len(protein_seq) < 30 or len(str(promoter_seq)) < 60:
                    continue

                # Build FASTA header: genome_id + double-underscore + protein_id
                try:
                    header = genome_id + '__' + feature.qualifiers['protein_id'][0]
                except (KeyError, IndexError):
                    header = 'unknown'

                protein_data  += '>%s\n%s\n' % (header, protein_seq)
                promoter_data += '>%s\n%s\n' % (header, promoter_seq)

        # Write protein FASTA
        with open('%s.faa' % genome_id, 'w') as f:
            f.write(protein_data)

        # Write promoter FASTA
        with open('%s.fa' % genome_id, 'w') as f:
            f.write(promoter_data)

        print('Finished processing genome: %s' % genome_id)

    except Exception as e:
        print('Error processing genome %s: %s' % (genome_id, e))
        raise

# %% [markdown]
# ## 4 — Parallel Sequence Extraction

# %%
from multiprocessing import Pool


def extract_protein(taxonomy: str) -> None:
    """
    Run the `all()` extractor in parallel over every genome in a taxon.

    Uses Python's multiprocessing.Pool to process all genomes concurrently,
    then moves the resulting .faa and .fa files into the correct sub-directories.

    Parameters
    ----------
    taxonomy : taxon name matching the folder created by download_gbk()
    """
    gbk_dir = os.path.join(BASE_DIR, '0_gbk', taxonomy)
    os.chdir(gbk_dir)

    genome_files = os.listdir(gbk_dir)
    print('Extracting sequences from %d genomes...' % len(genome_files))

    # Process all genomes in parallel (one worker per genome)
    with Pool(THREADS) as p:
        p.map(all, genome_files)

    # Move output files into their respective directories
    os.system('mv *.fa  %s/0_promoter/%s/' % (BASE_DIR, taxonomy))
    os.system('mv *.faa %s/0_protein/%s/'  % (BASE_DIR, taxonomy))

# %% [markdown]
# ## 5 — NCBI Protein Download

# %%
def get_selected_protein(protein_list) -> None:
    """
    Fetch protein sequences from NCBI Entrez and save each one as a
    separate FASTA file named by its accession.

    The function accepts either a single accession string (used for the
    connectivity test in check_before_task) or a list of accessions.

    Parameters
    ----------
    protein_list : str or list of str
        One or more RefSeq protein accession IDs (e.g. 'WP_005017521.1')
    """
    # Fetch all requested sequences in a single Entrez call (batch retrieval)
    data = Entrez.efetch(db='protein', id=protein_list, rettype='fasta')

    current_file = None
    for line in data:
        if '>' in line:
            # Close the previous file if one is open
            if current_file is not None:
                current_file.close()
            # Start a new file named by the bare accession (strip '>' and description)
            accession = line.split(' ')[0].strip().lstrip('>')
            current_file = open(accession, 'w')
        if current_file is not None:
            current_file.write(line)

    # Close the last file
    if current_file is not None:
        current_file.close()

# %% [markdown]
# ## 6 — DIAMOND Database Construction

# %%
def diamond_task(taxonomy: str) -> None:
    """
    Build a DIAMOND protein database from all extracted protein sequences
    for a given taxon.

    Steps
    -----
    1. Concatenate all .faa files into a single all_protein.faa
    2. Build the DIAMOND binary database (all_protein.dmnd)

    The database is stored in BASE_DIR/0_protein/<taxonomy>/ and reused
    for all subsequent user queries on the same taxon.

    Parameters
    ----------
    taxonomy : taxon name matching the folder created by extract_protein()
    """
    protein_dir = os.path.join(BASE_DIR, '0_protein', taxonomy)
    os.chdir(protein_dir)

    # Merge all individual genome protein files into one large FASTA
    os.system('cat *.faa > all_protein.faa')

    # Build the DIAMOND database; -p sets the thread count
    os.system('diamond makedb --in all_protein.faa -p %d -d all_protein.dmnd' % THREADS)

# %% [markdown]
# ## 7 — Promoter Lookup

# %%
def find_promoter(genome_id: str, protein_id: str, taxonomy: str, form: str) -> str:
    """
    Look up and return the FASTA entry for a specific protein or promoter
    from the pre-extracted per-genome FASTA files.

    Parameters
    ----------
    genome_id  : numeric genome accession (e.g. "000001405")
    protein_id : RefSeq protein accession (e.g. "WP_005017521.1")
    taxonomy   : taxon name (used to find the correct sub-directory)
    form       : 'protein' to retrieve from .faa, anything else for .fa (promoter)

    Returns
    -------
    A FASTA-formatted string for the matching entry, or a dummy AAAAAA
    sequence if the protein_id is not found (so downstream tools still receive
    a valid FASTA record).
    """
    # Choose the correct FASTA file based on form
    if form == 'protein':
        fasta_path = os.path.join(BASE_DIR, '0_protein', taxonomy, '%s.faa' % genome_id)
    else:
        fasta_path = os.path.join(BASE_DIR, '0_promoter', taxonomy, '%s.fa' % genome_id)

    data = ''
    writing = False

    with open(fasta_path) as f:
        for line in f:
            if line.startswith('>'):
                if writing:
                    # We have collected all lines for the target entry
                    return data
                if protein_id in line:
                    writing = True   # start collecting lines for this entry
            if writing:
                data += line

    # If we reach the end of the file without finding the protein, return a placeholder
    return '>%s\nAAAAAA\n' % protein_id

# %% [markdown]
# ## 8 — DIAMOND Search + Promoter Extraction

# %%
import pandas as pd


def get_selected_protein_diamond(protein_list: list, taxonomy: str, ntime: str) -> None:
    """
    For each user-supplied protein, find its homologs across the taxon and
    collect the corresponding upstream promoter sequences.

    Pipeline for each protein
    -------------------------
    1. Run DIAMOND BLASTP against the pre-built taxon database.
       - e-value threshold: 1e-20  (high-confidence homologs only)
       - Up to 500 hits returned per query (-k 500)
       - Uses /dev/shm as a temp dir for speed
    2. Extract the promoter sequence for each hit from the pre-computed .fa files.
    3. Cluster promoters with CD-HIT at 85% identity (-c 0.85) to remove
       near-duplicate sequences from closely related strains.

    Directory layout created under BASE_DIR/99_User_project/<ntime>/
    -----------------------------------------------------------------
    0_selected_protein/  — query protein FASTA files from NCBI
    1_diamond_result/    — raw DIAMOND tabular output
    2_promoter/          — clustered promoter FASTA files (one per protein)
    3_meme_result/       — placeholder, filled by combine_meme_work()

    Parameters
    ----------
    protein_list : list of RefSeq protein accessions supplied by the user
    taxonomy     : taxon name
    ntime        : unique job identifier (timestamp string)
    """
    job_dir = os.path.join(BASE_DIR, '99_User_project', ntime)

    # Create the job directory structure
    for subdir in ['0_selected_protein', '1_diamond_result', '2_promoter', '3_meme_result']:
        os.makedirs(os.path.join(job_dir, subdir), exist_ok=True)

    selected_dir = os.path.join(job_dir, '0_selected_protein')
    diamond_dir  = os.path.join(job_dir, '1_diamond_result')
    promoter_dir = os.path.join(job_dir, '2_promoter')
    db_path      = os.path.join(BASE_DIR, '0_protein', taxonomy, 'all_protein.dmnd')

    # Download the query protein sequences from NCBI
    os.chdir(selected_dir)
    get_selected_protein(protein_list)

    for protein in protein_list:
        os.chdir(selected_dir)

        # --- Step 1: DIAMOND BLASTP ---
        # -b 10.0 increases the block size for faster search on large databases
        os.system(
            'diamond blastp -d %s -q %s -o %s/%s '
            '-t /dev/shm -b 10.0 -k 500 -p %d'
            % (db_path, protein, diamond_dir, protein, THREADS)
        )

        # --- Step 2: Filter DIAMOND results and extract promoters ---
        result_path = os.path.join(diamond_dir, protein)
        diamond_result = pd.read_csv(
            result_path, sep='\t|;', engine='python', header=None
        )
        # Keep only high-confidence hits (e-value < 1e-20, column index 10)
        diamond_result = diamond_result.loc[diamond_result.iloc[:, 10] < 1e-20, :]

        # Write the promoter sequences for all high-confidence homologs
        out_path = os.path.join(promoter_dir, protein)
        with open(out_path, 'w') as out_f:
            for hit in diamond_result.iloc[:, 1]:
                # DIAMOND subject IDs have format: <genome_id>__<protein_id>
                genome, prot_id = hit.split('__')
                out_f.write(find_promoter(genome, prot_id, taxonomy, 'promoter'))

        # --- Step 3: CD-HIT clustering ---
        # Remove near-duplicate promoters (from closely related strains)
        # to avoid biasing the motif discovery toward over-represented sequences.
        # -c 0.85 = 85% identity threshold; -n 2 = word size for nucleotides
        os.chdir(promoter_dir)
        os.system('cd-hit -i %s -c 0.85 -o cd-hit_%s -T %d -n 2' % (protein, protein, THREADS))
        os.system('mv cd-hit_%s %s' % (protein, protein))   # overwrite with clustered version
        os.system('rm -f cd-hit*')                           # remove CD-HIT auxiliary files

# %% [markdown]
# ## 9 — MEME Motif Discovery (Single Combination)

# %%
def meme_work(ntime: str, set_length: int, combination: tuple) -> None:
    """
    Run MEME on one gene combination to search for shared promoter motifs.

    Two MEME runs are performed per combination:
      1. Standard run   — searches both strands for any motif.
      2. Palindrome run — adds the -pal flag, restricting to palindromic motifs
                          (common in bacterial transcription factor binding sites).

    Promoter sequences from all genes in the combination are merged into a
    single temporary FASTA file stored in /dev/shm (RAM disk) for speed.

    MEME parameters used
    ---------------------
    -dna          : nucleotide alphabet
    -minw 12      : minimum motif width 12 bp
    -maxw 25      : maximum motif width 25 bp
    -mod zoops    : zero or one occurrence per sequence (suits promoter analysis)
    -evt 1e-35    : E-value threshold for reporting motifs (standard)
    -evt 1e-20    : E-value threshold for palindrome motifs (relaxed slightly)
    -nmotifs 2    : report up to 2 motifs per run
    -p 4          : 4 threads per MEME run

    Successful results (≥ 5 output files) are moved from /dev/shm to the
    persistent results directory; failed/empty runs are discarded.

    Parameters
    ----------
    ntime       : unique job identifier
    set_length  : number of genes in the combination (unused here, kept for API)
    combination : tuple of protein accession strings (the gene combination)
    """
    promoter_dir  = os.path.join(BASE_DIR, '99_User_project', ntime, '2_promoter')
    meme_out_base = os.path.join(BASE_DIR, '99_User_project', ntime, '3_meme_result')
    shm_dir       = os.path.join('/dev/shm', ntime)

    os.chdir(promoter_dir)

    # Create a filename that encodes all gene names (used as MEME output folder name)
    file_name = '-'.join(combination)

    # Merge promoter sequences from all genes in this combination
    merged_data = ''.join(open(name).read() for name in combination)
    tmp_fasta = os.path.join(shm_dir, file_name)
    with open(tmp_fasta, 'w') as f:
        f.write(merged_data)

    os.chdir(shm_dir)

    # --- Standard MEME run ---
    os.system(
        '%s %s -oc %s/meme/%s -dna -minw 12 -maxw 25 '
        '-mod zoops -evt 1e-35 -p 4 -nmotifs 2'
        % (MEME_BIN, file_name, shm_dir, file_name)
    )

    # --- Palindrome MEME run (-pal enforces reverse-complement symmetry) ---
    os.system(
        '%s %s -oc %s/pal/%s -dna -minw 12 -maxw 25 '
        '-mod zoops -evt 1e-20 -pal -p 4 -nmotifs 2'
        % (MEME_BIN, file_name, shm_dir, file_name)
    )

    # Move results from RAM disk to persistent storage (only if MEME produced output)
    try:
        if len(os.listdir('%s/meme/%s' % (shm_dir, file_name))) >= 5:
            os.system('mv %s/meme/%s %s/meme/%s' % (shm_dir, file_name, meme_out_base, file_name))
        if len(os.listdir('%s/pal/%s' % (shm_dir, file_name))) >= 5:
            os.system('mv %s/pal/%s  %s/pal/%s'  % (shm_dir, file_name, meme_out_base, file_name))
    except Exception as e:
        # Log failed combinations for debugging without crashing the whole pool
        with open(os.path.join(BASE_DIR, ntime + '_errors.log'), 'a') as err_f:
            err_f.write('Failed combination: %s — %s\n' % (str(combination), str(e)))

# %% [markdown]
# ## 10 — Orchestration: All Combinations

# %%
from itertools import combinations
from functools import partial


def combine_meme_work(ntime: str, set_length: int) -> None:
    """
    Dispatch MEME jobs for all gene combinations, or run in comparative-only mode.

    Mode 0 — Comparative genomics only (set_length == 0)
    -----------------------------------------------------
    All promoters from all proteins are merged into one file and MEME is run
    once.  This mode uses more threads (-p 20) since there is only one job.

    Mode 1 / 2 / 3 — Combinatorial sampling
    ----------------------------------------
    MEME is run on every C(n, set_length) combination of the n input proteins.
    Jobs run in parallel via multiprocessing.Pool (up to 30 concurrent MEME
    processes, each using 4 threads).

    Parameters
    ----------
    ntime      : unique job identifier
    set_length : 0 = comparative only; 1/2/3 = genes per combination
    """
    promoter_dir  = os.path.join(BASE_DIR, '99_User_project', ntime, '2_promoter')
    meme_out_base = os.path.join(BASE_DIR, '99_User_project', ntime, '3_meme_result')
    shm_dir       = os.path.join('/dev/shm', ntime)

    # Set up output directories (persistent and RAM-disk)
    for path in [meme_out_base, shm_dir,
                 os.path.join(meme_out_base, 'meme'), os.path.join(meme_out_base, 'pal'),
                 os.path.join(shm_dir, 'meme'),        os.path.join(shm_dir, 'pal')]:
        os.makedirs(path, exist_ok=True)

    protein_files = os.listdir(promoter_dir)

    if set_length == 0:
        # --- Mode 0: single comparative run across all promoters ---
        os.chdir(promoter_dir)
        os.system('cat * > all_promoter')

        # Standard run
        os.system(
            '%s all_promoter -oc %s/meme/ -dna -minw 12 -maxw 25 '
            '-mod zoops -evt 1e-35 -p 20 -nmotifs 3' % (MEME_BIN, meme_out_base)
        )
        # Palindrome run
        os.system(
            '%s all_promoter -oc %s/pal/ -dna -minw 12 -maxw 25 '
            '-mod zoops -evt 1e-20 -pal -p 20 -nmotifs 3' % (MEME_BIN, meme_out_base)
        )

    else:
        # --- Mode 1/2/3: run MEME on every C(n, set_length) combination ---
        all_combos = list(combinations(protein_files, set_length))
        print('Running MEME on %d combination(s) with set_length=%d...' % (len(all_combos), set_length))

        # Use up to 30 parallel MEME processes (each uses 4 threads internally)
        with Pool(30) as p:
            p.map(partial(meme_work, ntime, set_length), all_combos)

    # Clean up temporary RAM-disk directory
    os.system('rm -rf %s' % shm_dir)

# %% [markdown]
# ## 11 — R Visualization and Summary

# %%
def motif_for_R(ntime: str) -> None:
    """
    Call motif.R to filter, merge, and visualise motifs for both the standard
    and palindrome MEME result directories.

    motif.R is run in the relevant result directory so it can use
    list.files() to discover its inputs automatically.

    Parameters
    ----------
    ntime : unique job identifier
    """
    meme_out_base = os.path.join(BASE_DIR, '99_User_project', ntime, '3_meme_result')

    for sub in ['meme', 'pal']:
        target_dir = os.path.join(meme_out_base, sub)
        os.chdir(target_dir)
        # Run the R script; it reads from the current directory and writes
        # novel_motif.png and Motif_<n> files in place.
        os.system('%s %s' % (RSCRIPT, MOTIF_R))
        summary_R_result()


def summary_R_result() -> None:
    """
    Aggregate all per-motif frequency tables written by motif.R into a single
    summary.txt file in the current directory, then delete the individual files.

    Each Motif_<n> file (written by motif.R) contains a CSV table of how often
    each input protein contributed to the merged motif.
    """
    with open('summary.txt', 'w') as summary_f:
        for filename in sorted(os.listdir('.')):
            if not filename.startswith('Motif'):
                continue
            summary_f.write(filename + '\n')
            with open(filename) as motif_f:
                for line in motif_f:
                    summary_f.write(line)

    # Remove individual Motif_<n> files now that they are merged into summary.txt
    os.system('rm -f Motif*')
